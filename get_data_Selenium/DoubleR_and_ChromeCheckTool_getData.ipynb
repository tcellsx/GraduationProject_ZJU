# %% [markdown]
# ### 双R
# #### CS/BS
# #### 爬虫就是模拟C端发送请求。
# #### Request（我们自己构造的）/Response（服务器返回的）。
# #### 请求包含3部分：请求行/头/体   （相应同理）。
# #### 需要模拟请求行、头、体。
#
# ### Chrome检查工具
# #### 箭头：箭头划到哪些元素就会显示对应的那段代码。
# #### PC/PAD/PHONE界面类型选择，当PC版本抓取不到可以尝试使用其他类型的界面。
# #### Elements：显示当前页面对应的HTML。
# #### Console：控制台、终端，前端开发打印日志输出的位置，写js代码进行调试。
# #### Source：从服务器当中获取的原始数据、支持断点调试。（与Elements区别：ELements是渲染过的Source）
# #### Network：抓包的地方，双R在这里找。
# #### Application：网站应用的一些资源，存储信息用（Cookie，缓存）。

# %% [markdown]
# ### Request获取动态、静态数据

# %% [markdown]
# ### 使用Python自己构造请求
# - 需要一个网络库
# - 这里使用python中最常用的最火的requests库

# %%
# !pip install requests

# %%
import requests

# %% [markdown]
# ### 请求的构成
# - 请求行
# - 请求头
# - 请求体（在提交当中）

# %%
headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36"
}

# %%
url = "https://www.xinpianchang.com/discover/article?from=navigator"

# %%
response = requests.request("GET",url,headers=headers)

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# ### 显示状态码

# %%
response.text
# Out:
# '<!DOCTYPE html><html lang="zh-cn"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1.0 viewport-fit=cover"/><meta name="theme-color" content="white"/><title>原创视频作品精选-海量高清无水印视频案例学习下载精选-新片场</title><meta name="robots" content="index,follow"/><meta name="description" content="新片场社区汇聚全球优秀创作人和海量精选原创短视频作品,覆盖广告,宣传片,剧情短片,创意混剪,婚礼,纪录片,特殊摄影,旅拍,Vlog,影视干货教程,音乐MV等无水印高清视频案例学习下载。"/><meta property="og:title" content="原创视频作品精选-海量高清无水印视频案例学习下载精选-新片场"/><meta property="og:description" content="新片场社区汇聚全球优秀创作人和海量精选原创短视频作品,覆盖广告,宣传片,剧情短片,创意混剪,婚礼,纪录片,特殊摄影,旅拍,Vlog,影视干货教程,音乐MV等无水印高清视频案例学习下载。"/><meta property="og:url" content="https://www.xinpianchang.com/discover/article-0-0-all-all-0-0-hot"/><meta property="og:type" content="discover"/><meta property="og:image" content="https://oss-xpc0.xpccdn.com/Upload/edu/2022/06/02629881408a499.png"/><meta property="og:site_name" content="新片场"/><link rel="canonical" href="https://www.xinpianchang.com/discover/article-0-0-all-all
# ...

# %% [markdown]
# ### CTRL+F 查找关键字段

# %% [markdown]
# ### 静态加载的资源给好URL和请求头就行
# ### 动态资源需要分析
# - 就是分析内容在哪个地方

# %%
comment_url = "https://www.xinpianchang.com/api/xpc/comments/article/v2?article_id=12658559"

# %%
response_comment = requests.get(comment_url,headers=headers)

# %%
response_comment.text
# Out:
# '{"status":0,"code":"_200","message":"OK","data":{"total":35,"page_size":12,"next_page_url":"/comments/article/v2?article_id=12658559&page=2","list":[{"id":1976241,"resource_id":12658559,"userid":13843928,"content":"适合女性的小车车·","addtime":1692091835,"count_approve":0,"referid":0,"from":0,"top_time":0,"is_top":false,"ip_location":"广东","userInfo":{"id":13843928,"url":"newstudios://app.xinpianchang.com/user/13843928","web_url":"https://www.xinpianchang.com/u13843928","username":"梁若鸿","avatar":"https://oss-xpc0.xpccdn.com/passport/avatar/13843928/2023/6/649b7ce17a97b.jpg","about":"","verify_description":"","sex":0,"is_vmovier_migrate_user":false,"is_stock_creator":false,"is_edu_supplier":false,"vip_flag":0,"vip_groups":[],"count":{"count_followee":5,"count_follower":0,"count_collected":0,"count_article_viewed":0,"count_liked":0,"count_like":0,"count_article":0,"count_popularity":0,"count_recommend":0,"count_recommend_rank":0,"count_creative_recommend":0,"count_collection":0,"count_hot_rank
# ...

# %%
response_comment.json()
# Out:
# {'status': 0,
#  'code': '_200',
#  'message': 'OK',
#  'data': {'total': 35,
#   'page_size': 12,
#   'next_page_url': '/comments/article/v2?article_id=12658559&page=2',
#   'list': [{'id': 1976241,
#     'resource_id': 12658559,
#     'userid': 13843928,
#     'content': '适合女性的小车车·',
#     'addtime': 1692091835,
#     'count_approve': 0,
#     'referid': 0,
#     'from': 0,
#     'top_time': 0,
#     'is_top': False,
#     'ip_location': '广东',
#     'userInfo': {'id': 13843928,
#      'url': 'newstudios://app.xinpianchang.com/user/13843928',
#      'web_url': 'https://www.xinpianchang.com/u13843928',
#      'username': '梁若鸿',
#      'avatar': 'https://oss-xpc0.xpccdn.com/passport/avatar/13843928/2023/6/649b7ce17a97b.jpg',
#      'about': '',
#      'verify_description': '',
#      'sex': 0,
#      'is_vmovier_migrate_user': False,
#      'is_stock_creator': False,
#      'is_edu_supplier': False,
#      'vip_flag': 0,
#      'vip_groups': [],
#      'count': {'count_followee': 5,
# ...
